# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('pic.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3000x2000 at 0x111754790>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (2000, 3000, 3)

# %%
pic_red = pic_arr.copy()

# %%
# R G B
pic_red[:,:,0]
# Out:
# array([[239, 239, 239, ..., 237, 237, 237],
#        [239, 239, 239, ..., 237, 237, 237],
#        [239, 239, 239, ..., 237, 237, 237],
#        ...,
#        [ 42,  42,  42, ...,  47,  47,  47],
#        [ 42,  42,  42, ...,  47,  47,  47],
#        [ 42,  42,  42, ...,  57,  57,  57]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
plt.imshow(pic_red[:,:,1],cmap='gray')

# %%
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
# Remove green channel
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
# remove blue channel
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)
